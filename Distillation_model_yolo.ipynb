# %% [markdown]
# <a href="https://colab.research.google.com/github/thanhdangg/Knowledge-Distillation-for-Object-Detection/blob/main/Distillation_model_yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets

# Check if GPU is available, and if not, use the CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
import torch.nn.functional as F
from torchvision.datasets import VOCDetection
from torchvision import transforms
import torch
from torch.utils.data import DataLoader

# %%
student_model = torch.hub.load("ultralytics/yolov5", "yolov5s")
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-8-31 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
# !pip install dill
# Out:
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (0.3.8)

# %%
teacher_model = torch.hub.load("ultralytics/yolov5", "yolov5x6")
teacher_model.eval()
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-8-31 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5x6 summary: 574 layers, 140730220 parameters, 0 gradients, 209.6 GFLOPs
# Adding AutoShape...
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 80, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(80, 160, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(160, 80, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(160, 80, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): Conv(
#           (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (4): C3(
#           (cv1): Conv(
#             (conv): Conv2d(320, 160, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(320, 160, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (4): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (5): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (6): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (7): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (5): Conv(
#           (conv): Conv2d(320, 640, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (6): C3(
#           (cv1): Conv(
#             (conv): Conv2d(640, 320, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(640, 320, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (4): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (5): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (6): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (7): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (8): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (9): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (10): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (11): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (7): Conv(
#           (conv): Conv2d(640, 960, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (8): C3(
#           (cv1): Conv(
#             (conv): Conv2d(960, 480, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(960, 480, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(960, 960, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (9): Conv(
#           (conv): Conv2d(960, 1280, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (10): C3(
#           (cv1): Conv(
#             (conv): Conv2d(1280, 640, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1280, 640, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(1280, 1280, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (11): SPPF(
#           (cv1): Conv(
#             (conv): Conv2d(1280, 640, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(2560, 1280, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         )
#         (12): Conv(
#           (conv): Conv2d(1280, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (13): Upsample(scale_factor=2.0, mode='nearest')
#         (14): Concat()
#         (15): C3(
#           (cv1): Conv(
#             (conv): Conv2d(1920, 480, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1920, 480, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(960, 960, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (16): Conv(
#           (conv): Conv2d(960, 640, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (17): Upsample(scale_factor=2.0, mode='nearest')
#         (18): Concat()
#         (19): C3(
#           (cv1): Conv(
#             (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (20): Conv(
#           (conv): Conv2d(640, 320, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (21): Upsample(scale_factor=2.0, mode='nearest')
#         (22): Concat()
#         (23): C3(
#           (cv1): Conv(
#             (conv): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(640, 160, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (24): Conv(
#           (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (25): Concat()
#         (26): C3(
#           (cv1): Conv(
#             (conv): Conv2d(640, 320, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(640, 320, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (27): Conv(
#           (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (28): Concat()
#         (29): C3(
#           (cv1): Conv(
#             (conv): Conv2d(1280, 480, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1280, 480, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(960, 960, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (30): Conv(
#           (conv): Conv2d(960, 960, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (31): Concat()
#         (32): C3(
#           (cv1): Conv(
#             (conv): Conv2d(1920, 640, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1920, 640, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(1280, 1280, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (3): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (33): Detect(
#           (m): ModuleList(
#             (0): Conv2d(320, 255, kernel_size=(1, 1), stride=(1, 1))
#             (1): Conv2d(640, 255, kernel_size=(1, 1), stride=(1, 1))
#             (2): Conv2d(960, 255, kernel_size=(1, 1), stride=(1, 1))
#             (3): Conv2d(1280, 255, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#   )
# )

# %%
transform = transforms.Compose([
    transforms.Resize((640, 640)),
    transforms.ToTensor(),
])

# %%
# Load the VOC2012 dataset
train_dataset = VOCDetection(root='./data', year='2012', image_set='train', download=True, transform=transform)
val_dataset = VOCDetection(root='./data', year='2012', image_set='val', download=True, transform=transform)
# Out:
# Using downloaded and verified file: ./data/VOCtrainval_11-May-2012.tar
# Extracting ./data/VOCtrainval_11-May-2012.tar to ./data
# Using downloaded and verified file: ./data/VOCtrainval_11-May-2012.tar
# Extracting ./data/VOCtrainval_11-May-2012.tar to ./data

# %%
def custom_collate_fn(batch):
    # Loại bỏ các phần tử None
    batch = [b for b in batch if b is not None]

    # Tạo một danh sách chứa các ảnh và nhãn riêng biệt
    images = torch.stack([item[0] for item in batch], dim=0)
    targets = [item[1] for item in batch]

    return images, targets

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2, collate_fn=custom_collate_fn)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=2, collate_fn=custom_collate_fn)

# %%
import numpy as np

# %%
import torch
import numpy as np
import torch.optim as optim
import torch.nn as nn
from PIL import UnidentifiedImageError  # Import the exception class


def train(model, train_loader, epochs, learning_rate, device):
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    model.train()

    for epoch in range(epochs):
        running_loss = 0.0

        for batch in train_loader:
          try:
            images, targets = batch
            images = images.to(device)

            if images.size(0) == 0:
                continue  # Skip empty batch

            # YOLOv5 returns a list of outputs
            outputs = model(images)[0]  # Select the first output

            # Debugging: Print type and content of targets
            print(f"Type of targets: {type(targets)}")
            print(f"Content of targets: {targets}")

            # Extract numeric data from targets
            if isinstance(targets, dict):
                # Assuming the dictionary contains tensors or lists of tensors
                target_values = []
                for key, value in targets.items():
                    if isinstance(value, (list, np.ndarray, torch.Tensor)):
                        # Convert to numpy array if it's a tensor
                        if isinstance(value, torch.Tensor):
                            value = value.numpy()
                        target_values.append(value)
                    else:
                        print(f"Unexpected type in targets dictionary for key {key}: {type(value)}")

                if len(target_values) == 0:
                    print("No valid numeric data found in targets.")
                    continue

                # Flatten the list of arrays/tensors if necessary
                target_values = np.concatenate([np.array(v) for v in target_values], axis=0)
                targets_tensor = torch.tensor(target_values, dtype=torch.float).to(device)
            else:
                # Handle if targets is not a dictionary
                if isinstance(targets, (list, np.ndarray, torch.Tensor)):
                    # Convert to tensor directly
                    if isinstance(targets, torch.Tensor):
                        targets_tensor = targets.to(device)
                    else:
                        targets_tensor = torch.tensor(targets, dtype=torch.float).to(device)
                elif isinstance(targets, dict):
                    print(f"Unexpected dictionary type for targets: {targets}")
                    # Handle the dictionary case, e.g., extract relevant values
                    # targets_tensor = handle_dict(targets)
                else:
                    print(f"Unexpected type for targets: {type(targets)}")
                    continue


            # Compute the loss
            loss_fn = nn.MSELoss()  # Example loss function
            loss = loss_fn(outputs, targets_tensor)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
          except UnidentifiedImageError as e:
            print(f"Warning: Failed to load image: {e}")
            continue
          except Exception as e:
            print(f"Error during training: {e}")
            continue

        print(f"Epoch {epoch+1}/{epochs}, Loss: {running_loss / len(train_loader)}")

# %%
epochs = 5
learning_rate = 0.001

# %%
train(teacher_model, train_loader, epochs, learning_rate, device)
# Out:
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:865: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Type of targets: <class 'list'>
# Content of targets: [{'annotation': {'filename': '2010_005229.jpg', 'folder': 'VOC2012', 'object': [{'name': 'dog', 'bndbox': {'xmax': '282', 'xmin': '62', 'ymax': '400', 'ymin': '83'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '1'}], 'segmented': '0', 'size': {'depth': '3', 'height': '400', 'width': '293'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2010_002734.jpg', 'folder': 'VOC2012', 'object': [{'name': 'horse', 'bndbox': {'xmax': '222', 'xmin': '129', 'ymax': '152', 'ymin': '66'}, 'difficult': '0', 'occluded': '0', 'pose': 'Right', 'truncated': '0'}, {'name': 'horse', 'bndbox': {'xmax': '500', 'xmin': '261', 'ymax': '333', 'ymin': '1'}, 'difficult': '0', 'occluded': '0', 'pose': 'Frontal', 'truncated': '1'}], 'segmented': '0', 'size': {'depth': '3', 'height': '333', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2010_005755.jpg', 'folder': 'VOC2012', 'object': [{'name': 'chair', 'bndbox': {'xmax': '260', 'xmin': '143', 'ymax': '257', 'ymin': '225'}, 'difficult': '1', 'occluded': '1', 'pose': 'Frontal', 'truncated': '1'}, {'name': 'chair', 'bndbox': {'xmax': '392', 'xmin': '290', 'ymax': '261', 'ymin': '229'}, 'difficult': '1', 'occluded': '1', 'pose': 'Frontal', 'truncated': '1'}, {'name': 'diningtable', 'bndbox': {'xmax': '500', 'xmin': '1', 'ymax': '335', 'ymin': '245'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '1'}], 'segmented': '1', 'size': {'depth': '3', 'height': '335', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2009_004694.jpg', 'folder': 'VOC2012', 'object': [{'name': 'person', 'bndbox': {'xmax': '241', 'xmin': '118', 'ymax': '356', 'ymin': '82'}, 'difficult': '0', 'occluded': '1', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'person', 'bndbox': {'xmax': '387', 'xmin': '210', 'ymax': '356', 'ymin': '54'}, 'difficult': '0', 'occluded': '1', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'bottle', 'bndbox': {'xmax': '264', 'xmin': '230', 'ymax': '256', 'ymin': '205'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'person', 'bndbox': {'xmax': '486', 'xmin': '428', 'ymax': '306', 'ymin': '231'}, 'difficult': '0', 'occluded': '0', 'pose': 'Frontal', 'truncated': '1'}, {'name': 'car', 'bndbox': {'xmax': '139', 'xmin': '60', 'ymax': '219', 'ymin': '157'}, 'difficult': '0', 'occluded': '0', 'pose': 'Rear', 'truncated': '0'}], 'segmented': '0', 'size': {'depth': '3', 'height': '356', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2009', 'database': 'The VOC2009 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2009_003173.jpg', 'folder': 'VOC2012', 'object': [{'name': 'cow', 'bndbox': {'xmax': '317', 'xmin': '238', 'ymax': '269', 'ymin': '220'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'cow', 'bndbox': {'xmax': '126', 'xmin': '80', 'ymax': '266', 'ymin': '216'}, 'difficult': '0', 'occluded': '1', 'pose': 'Rear', 'truncated': '0'}], 'segmented': '0', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2009', 'database': 'The VOC2009 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2011_001173.jpg', 'folder': 'VOC2012', 'object': [{'name': 'cat', 'bndbox': {'xmax': '478', 'xmin': '2', 'ymax': '358', 'ymin': '61'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '0'}, {'name': 'sofa', 'bndbox': {'xmax': '500', 'xmin': '1', 'ymax': '375', 'ymin': '117'}, 'difficult': '1', 'occluded': '1', 'pose': 'Unspecified', 'truncated': '1'}], 'segmented': '0', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2011', 'database': 'The VOC2011 Database', 'image': 'fli ...
# Error during training: must be real number, not dict
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:865: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Type of targets: <class 'list'>
# Content of targets: [{'annotation': {'folder': 'VOC2012', 'filename': '2008_001986.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '300', 'height': '500', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'bicycle', 'pose': 'Left', 'truncated': '0', 'occluded': '1', 'bndbox': {'xmin': '49', 'ymin': '241', 'xmax': '286', 'ymax': '379'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Left', 'truncated': '0', 'occluded': '1', 'bndbox': {'xmin': '69', 'ymin': '190', 'xmax': '236', 'ymax': '354'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Frontal', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '192', 'ymin': '1', 'xmax': '276', 'ymax': '151'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Frontal', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '91', 'ymin': '1', 'xmax': '183', 'ymax': '151'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Frontal', 'truncated': '1', 'occluded': '0', 'bndbox': {'xmin': '1', 'ymin': '1', 'xmax': '31', 'ymax': '102'}, 'difficult': '1'}, {'name': 'person', 'pose': 'Frontal', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '278', 'ymin': '1', 'xmax': '300', 'ymax': '151'}, 'difficult': '1'}, {'name': 'person', 'pose': 'Frontal', 'truncated': '0', 'occluded': '1', 'bndbox': {'xmin': '30', 'ymin': '6', 'xmax': '105', 'ymax': '186'}, 'difficult': '0'}]}}, {'annotation': {'filename': '2011_001455.jpg', 'folder': 'VOC2012', 'object': [{'name': 'aeroplane', 'bndbox': {'xmax': '499', 'xmin': '422', 'ymax': '94', 'ymin': '44'}, 'difficult': '0', 'occluded': '0', 'pose': 'Left', 'truncated': '1'}, {'name': 'aeroplane', 'bndbox': {'xmax': '477', 'xmin': '316', 'ymax': '78', 'ymin': '26'}, 'difficult': '0', 'occluded': '1', 'pose': 'Left', 'truncated': '0'}, {'name': 'aeroplane', 'bndbox': {'xmax': '456', 'xmin': '1', 'ymax': '198', 'ymin': '38'}, 'difficult': '0', 'occluded': '0', 'pose': 'Right', 'truncated': '1'}, {'name': 'car', 'bndbox': {'xmax': '500', 'xmin': '236', 'ymax': '333', 'ymin': '142'}, 'difficult': '0', 'occluded': '0', 'pose': 'Left', 'truncated': '1'}], 'segmented': '0', 'size': {'depth': '3', 'height': '333', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2011', 'database': 'The VOC2011 Database', 'image': 'flickr'}}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_003819.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '500', 'height': '375', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'bicycle', 'pose': 'Right', 'truncated': '0', 'occluded': '1', 'bndbox': {'xmin': '293', 'ymin': '186', 'xmax': '422', 'ymax': '261'}, 'difficult': '0'}, {'name': 'bicycle', 'pose': 'Right', 'truncated': '0', 'occluded': '1', 'bndbox': {'xmin': '146', 'ymin': '187', 'xmax': '242', 'ymax': '254'}, 'difficult': '0'}, {'name': 'bicycle', 'pose': 'Right', 'truncated': '0', 'occluded': '1', 'bndbox': {'xmin': '65', 'ymin': '187', 'xmax': '137', 'ymax': '244'}, 'difficult': '0'}, {'name': 'bicycle', 'pose': 'Right', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '1', 'ymin': '189', 'xmax': '48', 'ymax': '242'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Right', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '322', 'ymin': '134', 'xmax': '394', 'ymax': '245'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Right', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '160', 'ymin': '143', 'xmax': '216', 'ymax': '248'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Right', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '74', 'ymin': '155', 'xmax': '115', 'ymax': '236'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Right', 'truncated': '1', 'occluded': '0', 'bndbox': {'xmin': '1', 'ymin': '158', 'xmax': '30', 'ymax': '218'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Frontal', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '459', 'ymin': '134', 'xmax': '487', 'ymax': '203'}, 'diffic ...
# Error during training: must be real number, not dict
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:865: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Type of targets: <class 'list'>
# Content of targets: [{'annotation': {'folder': 'VOC2012', 'filename': '2008_002281.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '500', 'height': '375', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'boat', 'pose': 'Unspecified', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '409', 'ymin': '183', 'xmax': '456', 'ymax': '217'}, 'difficult': '0'}, {'name': 'boat', 'pose': 'Unspecified', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '417', 'ymin': '186', 'xmax': '425', 'ymax': '195'}, 'difficult': '1'}, {'name': 'boat', 'pose': 'Unspecified', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '425', 'ymin': '186', 'xmax': '431', 'ymax': '194'}, 'difficult': '1'}, {'name': 'boat', 'pose': 'Unspecified', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '429', 'ymin': '184', 'xmax': '434', 'ymax': '192'}, 'difficult': '1'}, {'name': 'boat', 'pose': 'Unspecified', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '400', 'ymin': '185', 'xmax': '406', 'ymax': '193'}, 'difficult': '1'}, {'name': 'boat', 'pose': 'Left', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '368', 'ymin': '175', 'xmax': '398', 'ymax': '188'}, 'difficult': '1'}, {'name': 'boat', 'pose': 'Unspecified', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '219', 'ymin': '175', 'xmax': '278', 'ymax': '226'}, 'difficult': '0'}, {'name': 'boat', 'pose': 'Unspecified', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '110', 'ymin': '180', 'xmax': '140', 'ymax': '203'}, 'difficult': '1'}, {'name': 'boat', 'pose': 'Unspecified', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '28', 'ymin': '182', 'xmax': '50', 'ymax': '201'}, 'difficult': '1'}, {'name': 'boat', 'pose': 'Unspecified', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '291', 'ymin': '186', 'xmax': '323', 'ymax': '208'}, 'difficult': '1'}, {'name': 'boat', 'pose': 'Unspecified', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '230', 'ymin': '184', 'xmax': '248', 'ymax': '200'}, 'difficult': '1'}, {'name': 'boat', 'pose': 'Unspecified', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '216', 'ymin': '183', 'xmax': '234', 'ymax': '196'}, 'difficult': '1'}, {'name': 'boat', 'pose': 'Left', 'truncated': '0', 'occluded': '1', 'bndbox': {'xmin': '259', 'ymin': '180', 'xmax': '279', 'ymax': '189'}, 'difficult': '1'}, {'name': 'boat', 'pose': 'Left', 'truncated': '0', 'occluded': '1', 'bndbox': {'xmin': '269', 'ymin': '175', 'xmax': '291', 'ymax': '187'}, 'difficult': '1'}]}}, {'annotation': {'filename': '2009_004134.jpg', 'folder': 'VOC2012', 'object': [{'name': 'horse', 'bndbox': {'xmax': '344', 'xmin': '108', 'ymax': '346', 'ymin': '60'}, 'difficult': '0', 'occluded': '1', 'pose': 'Left', 'truncated': '0'}, {'name': 'horse', 'bndbox': {'xmax': '452', 'xmin': '99', 'ymax': '352', 'ymin': '22'}, 'difficult': '0', 'occluded': '0', 'pose': 'Left', 'truncated': '0'}], 'segmented': '0', 'size': {'depth': '3', 'height': '364', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2009', 'database': 'The VOC2009 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2010_004953.jpg', 'folder': 'VOC2012', 'object': [{'name': 'bird', 'bndbox': {'xmax': '327', 'xmin': '181', 'ymax': '298', 'ymin': '43'}, 'difficult': '0', 'occluded': '0', 'pose': 'Frontal', 'truncated': '0'}], 'segmented': '0', 'size': {'depth': '3', 'height': '333', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2011_001971.jpg', 'folder': 'VOC2012', 'object': [{'name': 'cat', 'bndbox': {'xmax': '337', 'xmin': '1', 'ymax': '409', 'ymin': '91'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '0'}], 'segmented': '0', 'size': {'depth': '3', 'height': '500', 'width': '375'}, 'source': {'annotation': 'PASCAL VOC2011', 'database': 'The VOC2011 Database', 'image': 'flickr'}}}, {'annotation': ...
# Error during training: must be real number, not dict
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:865: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Type of targets: <class 'list'>
# Content of targets: [{'annotation': {'filename': '2010_001143.jpg', 'folder': 'VOC2012', 'object': [{'name': 'person', 'bndbox': {'xmax': '359', 'xmin': '337', 'ymax': '186', 'ymin': '132'}, 'difficult': '0', 'occluded': '0', 'pose': 'Rear', 'truncated': '0'}, {'name': 'person', 'bndbox': {'xmax': '376', 'xmin': '356', 'ymax': '185', 'ymin': '132'}, 'difficult': '0', 'occluded': '1', 'pose': 'Rear', 'truncated': '0'}, {'name': 'person', 'bndbox': {'xmax': '293', 'xmin': '282', 'ymax': '186', 'ymin': '126'}, 'difficult': '1', 'occluded': '1', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'train', 'bndbox': {'xmax': '304', 'xmin': '94', 'ymax': '251', 'ymin': '85'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '0'}], 'segmented': '0', 'size': {'depth': '3', 'height': '279', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2011_000682.jpg', 'folder': 'VOC2012', 'object': [{'name': 'chair', 'bndbox': {'xmax': '277', 'xmin': '123', 'ymax': '342', 'ymin': '74'}, 'difficult': '0', 'occluded': '0', 'pose': 'Frontal', 'truncated': '0'}, {'name': 'chair', 'bndbox': {'xmax': '430', 'xmin': '274', 'ymax': '339', 'ymin': '71'}, 'difficult': '0', 'occluded': '0', 'pose': 'Frontal', 'truncated': '0'}, {'name': 'chair', 'bndbox': {'xmax': '75', 'xmin': '1', 'ymax': '362', 'ymin': '87'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '1'}], 'segmented': '0', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2011', 'database': 'The VOC2011 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2010_005748.jpg', 'folder': 'VOC2012', 'object': [{'name': 'horse', 'bndbox': {'xmax': '269', 'xmin': '175', 'ymax': '273', 'ymin': '39'}, 'difficult': '0', 'occluded': '1', 'pose': 'Frontal', 'truncated': '0'}, {'name': 'person', 'bndbox': {'xmax': '266', 'xmin': '187', 'ymax': '171', 'ymin': '23'}, 'difficult': '0', 'occluded': '1', 'pose': 'Frontal', 'truncated': '0'}], 'segmented': '0', 'size': {'depth': '3', 'height': '333', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2009_003705.jpg', 'folder': 'VOC2012', 'object': [{'name': 'aeroplane', 'bndbox': {'xmax': '375', 'xmin': '1', 'ymax': '237', 'ymin': '18'}, 'difficult': '0', 'occluded': '1', 'pose': 'Frontal', 'truncated': '1'}, {'name': 'person', 'bndbox': {'xmax': '97', 'xmin': '77', 'ymax': '230', 'ymin': '174'}, 'difficult': '0', 'occluded': '0', 'pose': 'Right', 'truncated': '0'}, {'name': 'person', 'bndbox': {'xmax': '171', 'xmin': '144', 'ymax': '234', 'ymin': '174'}, 'difficult': '0', 'occluded': '0', 'pose': 'Rear', 'truncated': '0'}, {'name': 'person', 'bndbox': {'xmax': '269', 'xmin': '255', 'ymax': '216', 'ymin': '184'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '0'}, {'name': 'person', 'bndbox': {'xmax': '360', 'xmin': '301', 'ymax': '333', 'ymin': '145'}, 'difficult': '0', 'occluded': '0', 'pose': 'Rear', 'truncated': '0'}, {'name': 'person', 'bndbox': {'xmax': '419', 'xmin': '366', 'ymax': '333', 'ymin': '160'}, 'difficult': '0', 'occluded': '1', 'pose': 'Left', 'truncated': '0'}], 'segmented': '0', 'size': {'depth': '3', 'height': '333', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2009', 'database': 'The VOC2009 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2010_000939.jpg', 'folder': 'VOC2012', 'object': [{'name': 'aeroplane', 'bndbox': {'xmax': '399', 'xmin': '183', 'ymax': '230', 'ymin': '157'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '1'}], 'segmented': '0', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2010_004676.jpg', 'folder': 'VOC2012', 'object': [{'name' ...
# Error during training: must be real number, not dict
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:865: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Type of targets: <class 'list'>
# Content of targets: [{'annotation': {'filename': '2009_004829.jpg', 'folder': 'VOC2012', 'object': [{'name': 'bus', 'bndbox': {'xmax': '392', 'xmin': '86', 'ymax': '341', 'ymin': '37'}, 'difficult': '0', 'occluded': '0', 'pose': 'Rear', 'truncated': '0'}], 'segmented': '1', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2009', 'database': 'The VOC2009 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2011_002940.jpg', 'folder': 'VOC2012', 'object': [{'name': 'bottle', 'bndbox': {'xmax': '244', 'xmin': '216', 'ymax': '299', 'ymin': '208'}, 'difficult': '0', 'occluded': '1', 'pose': 'Unspecified', 'truncated': '0'}, {'name': 'bottle', 'bndbox': {'xmax': '260', 'xmin': '243', 'ymax': '232', 'ymin': '170'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '0'}, {'name': 'diningtable', 'bndbox': {'xmax': '386', 'xmin': '107', 'ymax': '375', 'ymin': '198'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '0'}, {'name': 'person', 'bndbox': {'xmax': '500', 'xmin': '372', 'ymax': '375', 'ymin': '113'}, 'difficult': '0', 'occluded': '0', 'pose': 'Left', 'truncated': '1'}, {'name': 'person', 'bndbox': {'xmax': '453', 'xmin': '332', 'ymax': '353', 'ymin': '92'}, 'difficult': '0', 'occluded': '1', 'pose': 'Left', 'truncated': '1'}, {'name': 'person', 'bndbox': {'xmax': '199', 'xmin': '81', 'ymax': '267', 'ymin': '120'}, 'difficult': '0', 'occluded': '1', 'pose': 'Frontal', 'truncated': '1'}, {'name': 'person', 'bndbox': {'xmax': '149', 'xmin': '2', 'ymax': '375', 'ymin': '116'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'bottle', 'bndbox': {'xmax': '239', 'xmin': '222', 'ymax': '229', 'ymin': '171'}, 'difficult': '0', 'occluded': '1', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'person', 'bndbox': {'xmax': '284', 'xmin': '238', 'ymax': '107', 'ymin': '48'}, 'difficult': '1', 'occluded': '1', 'pose': 'Frontal', 'truncated': '1'}], 'segmented': '0', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2011', 'database': 'The VOC2011 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2009_001098.jpg', 'folder': 'VOC2012', 'object': [{'name': 'bus', 'bndbox': {'xmax': '325', 'xmin': '1', 'ymax': '300', 'ymin': '1'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'bus', 'bndbox': {'xmax': '472', 'xmin': '305', 'ymax': '265', 'ymin': '37'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'person', 'bndbox': {'xmax': '65', 'xmin': '1', 'ymax': '225', 'ymin': '131'}, 'difficult': '0', 'occluded': '0', 'pose': 'Frontal', 'truncated': '1'}], 'segmented': '0', 'size': {'depth': '3', 'height': '300', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2009', 'database': 'The VOC2009 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2010_000183.jpg', 'folder': 'VOC2012', 'object': [{'name': 'dog', 'bndbox': {'xmax': '374', 'xmin': '79', 'ymax': '483', 'ymin': '133'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '0'}], 'segmented': '0', 'size': {'depth': '3', 'height': '500', 'width': '375'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2009_000197.jpg', 'folder': 'VOC2012', 'object': [{'name': 'person', 'bndbox': {'xmax': '423', 'xmin': '401', 'ymax': '178', 'ymin': '121'}, 'difficult': '0', 'occluded': '0', 'pose': 'Frontal', 'truncated': '0'}, {'name': 'bicycle', 'bndbox': {'xmax': '465', 'xmin': '418', 'ymax': '171', 'ymin': '155'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '0'}, {'name': 'bicycle', 'bndbox': {'xmax': '431', 'xmin': '376', 'ymax': '183', 'ymin': '162'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '0'}], 'segmented': '0', 'size': {'depth': '3', 'height': '400', 'width': '500'}, 's ...
# Error during training: must be real number, not dict
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:865: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Type of targets: <class 'list'>
# Content of targets: [{'annotation': {'folder': 'VOC2012', 'filename': '2008_000512.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '418', 'height': '500', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'bird', 'pose': 'Left', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '53', 'ymin': '50', 'xmax': '352', 'ymax': '498'}, 'difficult': '0'}]}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_000729.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '320', 'height': '240', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'person', 'pose': 'Frontal', 'truncated': '0', 'occluded': '1', 'bndbox': {'xmin': '4', 'ymin': '4', 'xmax': '295', 'ymax': '200'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Frontal', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '1', 'ymin': '1', 'xmax': '320', 'ymax': '240'}, 'difficult': '1'}]}}, {'annotation': {'filename': '2010_003159.jpg', 'folder': 'VOC2012', 'object': [{'name': 'motorbike', 'bndbox': {'xmax': '500', 'xmin': '1', 'ymax': '375', 'ymin': '1'}, 'difficult': '0', 'occluded': '0', 'pose': 'Left', 'truncated': '1'}], 'segmented': '0', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2010_004493.jpg', 'folder': 'VOC2012', 'object': [{'name': 'dog', 'bndbox': {'xmax': '499', 'xmin': '51', 'ymax': '378', 'ymin': '34'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'boat', 'bndbox': {'xmax': '40', 'xmin': '1', 'ymax': '53', 'ymin': '19'}, 'difficult': '1', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'boat', 'bndbox': {'xmax': '96', 'xmin': '30', 'ymax': '40', 'ymin': '20'}, 'difficult': '1', 'occluded': '1', 'pose': 'Unspecified', 'truncated': '0'}], 'segmented': '1', 'size': {'depth': '3', 'height': '380', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_002730.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '200', 'height': '258', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'person', 'pose': 'Frontal', 'truncated': '1', 'occluded': '0', 'bndbox': {'xmin': '1', 'ymin': '18', 'xmax': '182', 'ymax': '258'}, 'difficult': '0'}]}}, {'annotation': {'filename': '2009_000801.jpg', 'folder': 'VOC2012', 'object': [{'name': 'aeroplane', 'bndbox': {'xmax': '484', 'xmin': '25', 'ymax': '276', 'ymin': '116'}, 'difficult': '0', 'occluded': '0', 'pose': 'Right', 'truncated': '0'}], 'segmented': '1', 'size': {'depth': '3', 'height': '334', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2009', 'database': 'The VOC2009 Database', 'image': 'flickr'}}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_007022.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '500', 'height': '334', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'bird', 'pose': 'Left', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '246', 'ymin': '147', 'xmax': '293', 'ymax': '171'}, 'difficult': '0'}]}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_003831.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '500', 'height': '375', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'bird', 'pose': 'Right', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '62', 'ymin': '52', 'xmax': '341', 'ymax': '252'}, 'difficult': '0'}]}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_001498.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, ...
# Error during training: must be real number, not dict
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:865: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Type of targets: <class 'list'>
# Content of targets: [{'annotation': {'filename': '2011_000882.jpg', 'folder': 'VOC2012', 'object': [{'name': 'aeroplane', 'bndbox': {'xmax': '334', 'xmin': '2', 'ymax': '500', 'ymin': '162'}, 'difficult': '0', 'occluded': '0', 'pose': 'Rear', 'truncated': '1'}, {'name': 'person', 'bndbox': {'xmax': '237', 'xmin': '136', 'ymax': '179', 'ymin': '80'}, 'difficult': '0', 'occluded': '1', 'pose': 'Rear', 'truncated': '1'}], 'segmented': '1', 'size': {'depth': '3', 'height': '500', 'width': '334'}, 'source': {'annotation': 'PASCAL VOC2011', 'database': 'The VOC2011 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2010_002955.jpg', 'folder': 'VOC2012', 'object': [{'name': 'cat', 'bndbox': {'xmax': '328', 'xmin': '133', 'ymax': '174', 'ymin': '7'}, 'difficult': '0', 'occluded': '1', 'pose': 'Unspecified', 'truncated': '0'}, {'name': 'bird', 'bndbox': {'xmax': '341', 'xmin': '244', 'ymax': '302', 'ymin': '176'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '0'}], 'segmented': '0', 'size': {'depth': '3', 'height': '333', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2009_000130.jpg', 'folder': 'VOC2012', 'object': [{'name': 'bottle', 'bndbox': {'xmax': '275', 'xmin': '140', 'ymax': '493', 'ymin': '6'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '0'}], 'segmented': '0', 'size': {'depth': '3', 'height': '500', 'width': '333'}, 'source': {'annotation': 'PASCAL VOC2009', 'database': 'The VOC2009 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2011_000725.jpg', 'folder': 'VOC2012', 'object': [{'name': 'sofa', 'bndbox': {'xmax': '499', 'xmin': '1', 'ymax': '332', 'ymin': '165'}, 'difficult': '1', 'occluded': '1', 'pose': 'Frontal', 'truncated': '1'}, {'name': 'person', 'bndbox': {'xmax': '467', 'xmin': '41', 'ymax': '332', 'ymin': '36'}, 'difficult': '0', 'occluded': '0', 'pose': 'Frontal', 'truncated': '1'}, {'name': 'person', 'bndbox': {'xmax': '482', 'xmin': '199', 'ymax': '332', 'ymin': '33'}, 'difficult': '0', 'occluded': '0', 'pose': 'Frontal', 'truncated': '1'}], 'segmented': '0', 'size': {'depth': '3', 'height': '332', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2011', 'database': 'The VOC2011 Database', 'image': 'flickr'}}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_005902.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '375', 'height': '500', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'motorbike', 'pose': 'Frontal', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '80', 'ymin': '115', 'xmax': '237', 'ymax': '445'}, 'difficult': '0'}, {'name': 'bicycle', 'pose': 'Frontal', 'truncated': '1', 'occluded': '0', 'bndbox': {'xmin': '1', 'ymin': '79', 'xmax': '20', 'ymax': '134'}, 'difficult': '1'}, {'name': 'bicycle', 'pose': 'Rear', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '38', 'ymin': '78', 'xmax': '67', 'ymax': '130'}, 'difficult': '1'}, {'name': 'bicycle', 'pose': 'Unspecified', 'truncated': '0', 'occluded': '1', 'bndbox': {'xmin': '113', 'ymin': '91', 'xmax': '174', 'ymax': '121'}, 'difficult': '1'}, {'name': 'car', 'pose': 'Left', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '261', 'ymin': '52', 'xmax': '375', 'ymax': '126'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Right', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '214', 'ymin': '39', 'xmax': '248', 'ymax': '100'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Right', 'truncated': '0', 'occluded': '1', 'bndbox': {'xmin': '207', 'ymin': '41', 'xmax': '229', 'ymax': '96'}, 'difficult': '1'}, {'name': 'person', 'pose': 'Left', 'truncated': '0', 'occluded': '1', 'bndbox': {'xmin': '172', 'ymin': '39', 'xmax': '203', 'ymax': '105'}, 'difficult': '0'}, {'name': 'bicycle', 'pose': 'Unspecified', 'truncated': '0', 'occluded': '1', 'bndbox': {'xmin': '85', 'ymin ...
# Error during training: must be real number, not dict
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:865: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Type of targets: <class 'list'>
# Content of targets: [{'annotation': {'filename': '2010_001562.jpg', 'folder': 'VOC2012', 'object': [{'name': 'tvmonitor', 'bndbox': {'xmax': '500', 'xmin': '413', 'ymax': '252', 'ymin': '120'}, 'difficult': '0', 'occluded': '0', 'pose': 'Frontal', 'truncated': '1'}], 'segmented': '1', 'size': {'depth': '3', 'height': '334', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_008411.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '500', 'height': '375', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'aeroplane', 'pose': 'Frontal', 'truncated': '1', 'occluded': '0', 'bndbox': {'xmin': '58', 'ymin': '75', 'xmax': '500', 'ymax': '304'}, 'difficult': '0'}]}}, {'annotation': {'filename': '2010_003264.jpg', 'folder': 'VOC2012', 'object': [{'name': 'bicycle', 'bndbox': {'xmax': '500', 'xmin': '465', 'ymax': '339', 'ymin': '289'}, 'difficult': '1', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'bicycle', 'bndbox': {'xmax': '410', 'xmin': '314', 'ymax': '331', 'ymin': '254'}, 'difficult': '0', 'occluded': '1', 'pose': 'Right', 'truncated': '0'}, {'name': 'person', 'bndbox': {'xmax': '393', 'xmin': '328', 'ymax': '314', 'ymin': '214'}, 'difficult': '0', 'occluded': '1', 'pose': 'Right', 'truncated': '0'}, {'name': 'car', 'bndbox': {'xmax': '166', 'xmin': '1', 'ymax': '375', 'ymin': '235'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'car', 'bndbox': {'xmax': '500', 'xmin': '247', 'ymax': '375', 'ymin': '350'}, 'difficult': '1', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '1'}], 'segmented': '0', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2009_002083.jpg', 'folder': 'VOC2012', 'object': [{'name': 'sofa', 'bndbox': {'xmax': '304', 'xmin': '74', 'ymax': '355', 'ymin': '134'}, 'difficult': '0', 'occluded': '0', 'pose': 'Frontal', 'truncated': '0'}, {'name': 'pottedplant', 'bndbox': {'xmax': '231', 'xmin': '129', 'ymax': '160', 'ymin': '104'}, 'difficult': '0', 'occluded': '1', 'pose': 'Unspecified', 'truncated': '1'}], 'segmented': '1', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2009', 'database': 'The VOC2009 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2011_002598.jpg', 'folder': 'VOC2012', 'object': [{'name': 'motorbike', 'bndbox': {'xmax': '401', 'xmin': '1', 'ymax': '320', 'ymin': '142'}, 'difficult': '0', 'occluded': '0', 'pose': 'Left', 'truncated': '1'}, {'name': 'motorbike', 'bndbox': {'xmax': '266', 'xmin': '3', 'ymax': '229', 'ymin': '88'}, 'difficult': '0', 'occluded': '1', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'person', 'bndbox': {'xmax': '340', 'xmin': '231', 'ymax': '316', 'ymin': '44'}, 'difficult': '0', 'occluded': '1', 'pose': 'Left', 'truncated': '0'}, {'name': 'person', 'bndbox': {'xmax': '268', 'xmin': '112', 'ymax': '320', 'ymin': '73'}, 'difficult': '0', 'occluded': '1', 'pose': 'Left', 'truncated': '0'}, {'name': 'person', 'bndbox': {'xmax': '212', 'xmin': '78', 'ymax': '161', 'ymin': '29'}, 'difficult': '0', 'occluded': '1', 'pose': 'Left', 'truncated': '1'}, {'name': 'car', 'bndbox': {'xmax': '129', 'xmin': '1', 'ymax': '161', 'ymin': '12'}, 'difficult': '0', 'occluded': '1', 'pose': 'Left', 'truncated': '1'}, {'name': 'car', 'bndbox': {'xmax': '244', 'xmin': '197', 'ymax': '40', 'ymin': '8'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '0'}, {'name': 'car', 'bndbox': {'xmax': '309', 'xmin': '259', 'ymax': '41', 'ymin': '3'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '0'}, {'name': 'car', 'bndbox': {'xmax': '187', 'xmin': '138', 'ymax': '35', 'ymin': '1'}, 'difficult': '0 ...
# Error during training: must be real number, not dict
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:865: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Type of targets: <class 'list'>
# Content of targets: [{'annotation': {'folder': 'VOC2012', 'filename': '2008_006625.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '500', 'height': '375', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'diningtable', 'pose': 'Unspecified', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '1', 'ymin': '200', 'xmax': '436', 'ymax': '375'}, 'difficult': '1'}, {'name': 'person', 'pose': 'Unspecified', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '62', 'ymin': '1', 'xmax': '498', 'ymax': '311'}, 'difficult': '0'}, {'name': 'chair', 'pose': 'Frontal', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '29', 'ymin': '1', 'xmax': '126', 'ymax': '188'}, 'difficult': '1'}]}}, {'annotation': {'filename': '2009_002271.jpg', 'folder': 'VOC2012', 'object': [{'name': 'bicycle', 'bndbox': {'xmax': '300', 'xmin': '93', 'ymax': '310', 'ymin': '174'}, 'difficult': '0', 'occluded': '0', 'pose': 'Left', 'truncated': '0'}, {'name': 'bus', 'bndbox': {'xmax': '500', 'xmin': '303', 'ymax': '204', 'ymin': '1'}, 'difficult': '0', 'occluded': '0', 'pose': 'Left', 'truncated': '1'}, {'name': 'car', 'bndbox': {'xmax': '264', 'xmin': '1', 'ymax': '242', 'ymin': '120'}, 'difficult': '0', 'occluded': '1', 'pose': 'Left', 'truncated': '1'}, {'name': 'car', 'bndbox': {'xmax': '263', 'xmin': '184', 'ymax': '156', 'ymin': '125'}, 'difficult': '0', 'occluded': '1', 'pose': 'Left', 'truncated': '1'}], 'segmented': '0', 'size': {'depth': '3', 'height': '337', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2009', 'database': 'The VOC2009 Database', 'image': 'flickr'}}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_002543.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '375', 'height': '500', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'person', 'pose': 'Frontal', 'truncated': '1', 'occluded': '0', 'bndbox': {'xmin': '77', 'ymin': '254', 'xmax': '293', 'ymax': '500'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Right', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '11', 'ymin': '335', 'xmax': '64', 'ymax': '398'}, 'difficult': '1'}, {'name': 'person', 'pose': 'Frontal', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '54', 'ymin': '341', 'xmax': '70', 'ymax': '373'}, 'difficult': '1'}]}}, {'annotation': {'filename': '2010_003119.jpg', 'folder': 'VOC2012', 'object': [{'name': 'bird', 'bndbox': {'xmax': '384', 'xmin': '132', 'ymax': '185', 'ymin': '130'}, 'difficult': '0', 'occluded': '0', 'pose': 'Frontal', 'truncated': '0'}], 'segmented': '1', 'size': {'depth': '3', 'height': '317', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2010_002779.jpg', 'folder': 'VOC2012', 'object': [{'name': 'person', 'bndbox': {'xmax': '259', 'xmin': '1', 'ymax': '500', 'ymin': '203'}, 'difficult': '1', 'occluded': '0', 'pose': 'Rear', 'truncated': '1'}, {'name': 'person', 'bndbox': {'xmax': '322', 'xmin': '287', 'ymax': '450', 'ymin': '383'}, 'difficult': '0', 'occluded': '1', 'pose': 'Frontal', 'truncated': '1'}], 'segmented': '0', 'size': {'depth': '3', 'height': '500', 'width': '375'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_000416.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '375', 'height': '500', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'person', 'pose': 'Frontal', 'truncated': '1', 'occluded': '0', 'bndbox': {'xmin': '69', 'ymin': '169', 'xmax': '279', 'ymax': '499'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Unspecified', 'truncated': '1', 'occluded': '0', 'bndbox': {'xmin': '303', 'ymin': '169', 'xmax': '375', 'ymax': '500'}, 'difficult': '0'}]}}, {'annotation':  ...
# Error during training: must be real number, not dict
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:865: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Type of targets: <class 'list'>
# Content of targets: [{'annotation': {'filename': '2011_002273.jpg', 'folder': 'VOC2012', 'object': [{'name': 'person', 'bndbox': {'xmax': '309', 'xmin': '68', 'ymax': '500', 'ymin': '98'}, 'difficult': '0', 'occluded': '1', 'pose': 'Unspecified', 'truncated': '1'}], 'segmented': '0', 'size': {'depth': '3', 'height': '500', 'width': '333'}, 'source': {'annotation': 'PASCAL VOC2011', 'database': 'The VOC2011 Database', 'image': 'flickr'}}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_001444.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '500', 'height': '375', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'bottle', 'pose': 'Unspecified', 'truncated': '0', 'occluded': '1', 'bndbox': {'xmin': '291', 'ymin': '198', 'xmax': '342', 'ymax': '369'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Unspecified', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '9', 'ymin': '2', 'xmax': '500', 'ymax': '375'}, 'difficult': '0'}]}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_004280.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '500', 'height': '375', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'bicycle', 'pose': 'Left', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '17', 'ymin': '17', 'xmax': '500', 'ymax': '342'}, 'difficult': '0'}, {'name': 'chair', 'pose': 'Frontal', 'truncated': '0', 'occluded': '1', 'bndbox': {'xmin': '9', 'ymin': '26', 'xmax': '173', 'ymax': '310'}, 'difficult': '0'}, {'name': 'pottedplant', 'pose': 'Unspecified', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '269', 'ymin': '1', 'xmax': '334', 'ymax': '69'}, 'difficult': '1'}, {'name': 'diningtable', 'pose': 'Unspecified', 'truncated': '0', 'occluded': '1', 'bndbox': {'xmin': '152', 'ymin': '49', 'xmax': '440', 'ymax': '274'}, 'difficult': '1'}, {'name': 'chair', 'pose': 'Frontal', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '341', 'ymin': '92', 'xmax': '449', 'ymax': '226'}, 'difficult': '0'}]}}, {'annotation': {'filename': '2010_005350.jpg', 'folder': 'VOC2012', 'object': [{'name': 'person', 'bndbox': {'xmax': '319', 'xmin': '256', 'ymax': '337', 'ymin': '206'}, 'difficult': '0', 'occluded': '1', 'pose': 'Frontal', 'truncated': '0'}, {'name': 'person', 'bndbox': {'xmax': '366', 'xmin': '275', 'ymax': '341', 'ymin': '201'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '0'}, {'name': 'bird', 'bndbox': {'xmax': '116', 'xmin': '49', 'ymax': '327', 'ymin': '287'}, 'difficult': '0', 'occluded': '0', 'pose': 'Right', 'truncated': '0'}, {'name': 'bird', 'bndbox': {'xmax': '201', 'xmin': '162', 'ymax': '345', 'ymin': '262'}, 'difficult': '0', 'occluded': '0', 'pose': 'Rear', 'truncated': '0'}, {'name': 'bird', 'bndbox': {'xmax': '169', 'xmin': '140', 'ymax': '330', 'ymin': '286'}, 'difficult': '0', 'occluded': '1', 'pose': 'Rear', 'truncated': '0'}, {'name': 'bird', 'bndbox': {'xmax': '246', 'xmin': '201', 'ymax': '340', 'ymin': '298'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '0'}], 'segmented': '0', 'size': {'depth': '3', 'height': '500', 'width': '375'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_008180.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '500', 'height': '333', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'aeroplane', 'pose': 'Left', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '178', 'ymin': '111', 'xmax': '413', 'ymax': '194'}, 'difficult': '0'}, {'name': 'aeroplane', 'pose': 'Left', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '119', 'ymin': '175', 'xmax': '342', 'ymax': '253'}, 'difficult': '0'}]}}, {'annotation': {'filename': '2009_003614.jpg', 'folder': 'VOC2012', 'objec ...
# Error during training: must be real number, not dict
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:865: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Type of targets: <class 'list'>
# Content of targets: [{'annotation': {'filename': '2011_000359.jpg', 'folder': 'VOC2012', 'object': [{'name': 'aeroplane', 'bndbox': {'xmax': '284', 'xmin': '1', 'ymax': '355', 'ymin': '249'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '1'}], 'segmented': '1', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2011', 'database': 'The VOC2011 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2010_003677.jpg', 'folder': 'VOC2012', 'object': [{'name': 'chair', 'bndbox': {'xmax': '375', 'xmin': '1', 'ymax': '500', 'ymin': '1'}, 'difficult': '0', 'occluded': '1', 'pose': 'Frontal', 'truncated': '1'}, {'name': 'person', 'bndbox': {'xmax': '271', 'xmin': '38', 'ymax': '500', 'ymin': '94'}, 'difficult': '0', 'occluded': '0', 'pose': 'Frontal', 'truncated': '1'}], 'segmented': '0', 'size': {'depth': '3', 'height': '500', 'width': '375'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2009_001994.jpg', 'folder': 'VOC2012', 'object': [{'name': 'person', 'bndbox': {'xmax': '417', 'xmin': '91', 'ymax': '295', 'ymin': '31'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '0', 'part': [{'name': 'head', 'bndbox': {'xmin': '113', 'ymin': '32', 'xmax': '225', 'ymax': '152'}}, {'name': 'hand', 'bndbox': {'xmin': '143', 'ymin': '122', 'xmax': '214', 'ymax': '191'}}, {'name': 'hand', 'bndbox': {'xmin': '195', 'ymin': '266', 'xmax': '255', 'ymax': '289'}}, {'name': 'foot', 'bndbox': {'xmin': '383', 'ymin': '119', 'xmax': '419', 'ymax': '160'}}]}], 'segmented': '0', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2009', 'database': 'The VOC2009 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2011_001895.jpg', 'folder': 'VOC2012', 'object': [{'name': 'sofa', 'bndbox': {'xmax': '500', 'xmin': '1', 'ymax': '375', 'ymin': '141'}, 'difficult': '0', 'occluded': '1', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'person', 'bndbox': {'xmax': '494', 'xmin': '44', 'ymax': '375', 'ymin': '7'}, 'difficult': '0', 'occluded': '1', 'pose': 'Frontal', 'truncated': '1'}, {'name': 'person', 'bndbox': {'xmax': '500', 'xmin': '257', 'ymax': '375', 'ymin': '46'}, 'difficult': '0', 'occluded': '1', 'pose': 'Frontal', 'truncated': '1'}], 'segmented': '1', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2011', 'database': 'The VOC2011 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2010_005683.jpg', 'folder': 'VOC2012', 'object': [{'name': 'aeroplane', 'bndbox': {'xmax': '414', 'xmin': '7', 'ymax': '374', 'ymin': '99'}, 'difficult': '0', 'occluded': '0', 'pose': 'Frontal', 'truncated': '1'}, {'name': 'aeroplane', 'bndbox': {'xmax': '84', 'xmin': '7', 'ymax': '165', 'ymin': '133'}, 'difficult': '0', 'occluded': '0', 'pose': 'Left', 'truncated': '0'}], 'segmented': '0', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_001115.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '500', 'height': '375', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'person', 'pose': 'Unspecified', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '230', 'ymin': '48', 'xmax': '444', 'ymax': '375'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Unspecified', 'truncated': '1', 'occluded': '0', 'bndbox': {'xmin': '76', 'ymin': '16', 'xmax': '218', 'ymax': '238'}, 'difficult': '0'}]}}, {'annotation': {'filename': '2010_001481.jpg', 'folder': 'VOC2012', 'object': [{'name': 'bird', 'bndbox': {'xmax': '322', 'xmin': '233', 'ymax': '397', 'ymin': '305'}, 'difficult': '0', 'occluded': '0', 'pose': 'Left', 'truncated': '0'}], 'segmented': '0', 'size': {'depth ...
# Error during training: must be real number, not dict
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:865: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Type of targets: <class 'list'>
# ...
# Error during training: must be real number, not dict
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:865: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Type of targets: <class 'list'>
# Content of targets: [{'annotation': {'filename': '2009_005016.jpg', 'folder': 'VOC2012', 'object': [{'name': 'diningtable', 'bndbox': {'xmax': '500', 'xmin': '298', 'ymax': '375', 'ymin': '127'}, 'difficult': '0', 'occluded': '1', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'person', 'bndbox': {'xmax': '340', 'xmin': '171', 'ymax': '373', 'ymin': '75'}, 'difficult': '0', 'occluded': '1', 'pose': 'Right', 'truncated': '1'}, {'name': 'chair', 'bndbox': {'xmax': '456', 'xmin': '327', 'ymax': '128', 'ymin': '55'}, 'difficult': '0', 'occluded': '0', 'pose': 'Frontal', 'truncated': '1'}, {'name': 'chair', 'bndbox': {'xmax': '51', 'xmin': '1', 'ymax': '252', 'ymin': '70'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'chair', 'bndbox': {'xmax': '295', 'xmin': '60', 'ymax': '375', 'ymin': '153'}, 'difficult': '0', 'occluded': '1', 'pose': 'Right', 'truncated': '1'}], 'segmented': '1', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2009', 'database': 'The VOC2009 Database', 'image': 'flickr'}}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_006039.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '500', 'height': '375', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'diningtable', 'pose': 'Unspecified', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '1', 'ymin': '144', 'xmax': '385', 'ymax': '375'}, 'difficult': '1'}, {'name': 'person', 'pose': 'Unspecified', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '1', 'ymin': '137', 'xmax': '117', 'ymax': '303'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Unspecified', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '47', 'ymin': '76', 'xmax': '155', 'ymax': '242'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Unspecified', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '117', 'ymin': '77', 'xmax': '195', 'ymax': '238'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Unspecified', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '173', 'ymin': '73', 'xmax': '229', 'ymax': '186'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Frontal', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '243', 'ymin': '63', 'xmax': '328', 'ymax': '150'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Frontal', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '339', 'ymin': '69', 'xmax': '401', 'ymax': '198'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Unspecified', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '381', 'ymin': '84', 'xmax': '455', 'ymax': '285'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Left', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '400', 'ymin': '134', 'xmax': '500', 'ymax': '375'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Left', 'truncated': '1', 'occluded': '0', 'bndbox': {'xmin': '214', 'ymin': '120', 'xmax': '426', 'ymax': '375'}, 'difficult': '0'}]}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_001670.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '375', 'height': '500', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'person', 'pose': 'Unspecified', 'truncated': '1', 'occluded': '0', 'bndbox': {'xmin': '253', 'ymin': '308', 'xmax': '366', 'ymax': '467'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Left', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '62', 'ymin': '173', 'xmax': '281', 'ymax': '500'}, 'difficult': '0'}, {'name': 'person', 'pose': 'Frontal', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '16', 'ymin': '127', 'xmax': '99', 'ymax': '301'}, 'difficult': '0'}]}}, {'annotation': {'filename': '2009_002505.jpg', 'folder': 'VOC2012', 'object': [{'name': 'bus', 'bndbox': {'xmax': '500', 'xmin': '481', 'ymax': '178', 'ymin': '127'}, 'difficult': '0', 'occluded': '0', 'pose': 'Frontal', 'truncated': '1'}, {'name': ' ...
# Error during training: must be real number, not dict
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:865: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Type of targets: <class 'list'>
# Content of targets: [{'annotation': {'filename': '2009_000777.jpg', 'folder': 'VOC2012', 'object': [{'name': 'car', 'bndbox': {'xmax': '478', 'xmin': '5', 'ymax': '369', 'ymin': '32'}, 'difficult': '0', 'occluded': '0', 'pose': 'Left', 'truncated': '0'}, {'name': 'car', 'bndbox': {'xmax': '83', 'xmin': '1', 'ymax': '165', 'ymin': '101'}, 'difficult': '0', 'occluded': '1', 'pose': 'Left', 'truncated': '1'}, {'name': 'car', 'bndbox': {'xmax': '176', 'xmin': '66', 'ymax': '172', 'ymin': '98'}, 'difficult': '0', 'occluded': '1', 'pose': 'Rear', 'truncated': '1'}, {'name': 'person', 'bndbox': {'xmax': '481', 'xmin': '473', 'ymax': '153', 'ymin': '119'}, 'difficult': '0', 'occluded': '0', 'pose': 'Rear', 'truncated': '1'}, {'name': 'car', 'bndbox': {'xmax': '500', 'xmin': '486', 'ymax': '141', 'ymin': '124'}, 'difficult': '0', 'occluded': '0', 'pose': 'Right', 'truncated': '1'}], 'segmented': '0', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2009', 'database': 'The VOC2009 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2011_002143.jpg', 'folder': 'VOC2012', 'object': [{'name': 'car', 'bndbox': {'xmax': '273', 'xmin': '220', 'ymax': '361', 'ymin': '287'}, 'difficult': '0', 'occluded': '1', 'pose': 'Frontal', 'truncated': '1'}, {'name': 'car', 'bndbox': {'xmax': '167', 'xmin': '45', 'ymax': '387', 'ymin': '261'}, 'difficult': '0', 'occluded': '1', 'pose': 'Frontal', 'truncated': '1'}, {'name': 'car', 'bndbox': {'xmax': '186', 'xmin': '155', 'ymax': '368', 'ymin': '289'}, 'difficult': '0', 'occluded': '1', 'pose': 'Frontal', 'truncated': '1'}, {'name': 'car', 'bndbox': {'xmax': '221', 'xmin': '171', 'ymax': '347', 'ymin': '293'}, 'difficult': '0', 'occluded': '1', 'pose': 'Frontal', 'truncated': '1'}, {'name': 'car', 'bndbox': {'xmax': '295', 'xmin': '253', 'ymax': '383', 'ymin': '286'}, 'difficult': '0', 'occluded': '1', 'pose': 'Frontal', 'truncated': '1'}, {'name': 'car', 'bndbox': {'xmax': '332', 'xmin': '266', 'ymax': '394', 'ymin': '235'}, 'difficult': '1', 'occluded': '1', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'car', 'bndbox': {'xmax': '172', 'xmin': '1', 'ymax': '459', 'ymin': '106'}, 'difficult': '1', 'occluded': '1', 'pose': 'Unspecified', 'truncated': '1'}, {'name': 'car', 'bndbox': {'xmax': '245', 'xmin': '82', 'ymax': '195', 'ymin': '137'}, 'difficult': '0', 'occluded': '1', 'pose': 'Right', 'truncated': '1'}, {'name': 'car', 'bndbox': {'xmax': '375', 'xmin': '233', 'ymax': '247', 'ymin': '111'}, 'difficult': '0', 'occluded': '1', 'pose': 'Rear', 'truncated': '1'}], 'segmented': '0', 'size': {'depth': '3', 'height': '500', 'width': '375'}, 'source': {'annotation': 'PASCAL VOC2011', 'database': 'The VOC2011 Database', 'image': 'flickr'}}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_006361.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '375', 'height': '500', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'bicycle', 'pose': 'Frontal', 'truncated': '1', 'occluded': '0', 'bndbox': {'xmin': '52', 'ymin': '1', 'xmax': '345', 'ymax': '479'}, 'difficult': '0'}]}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_003297.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '500', 'height': '375', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'cow', 'pose': 'Left', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '158', 'ymin': '140', 'xmax': '334', 'ymax': '274'}, 'difficult': '0'}, {'name': 'cow', 'pose': 'Frontal', 'truncated': '1', 'occluded': '0', 'bndbox': {'xmin': '53', 'ymin': '84', 'xmax': '75', 'ymax': '112'}, 'difficult': '1'}]}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_007825.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '500', 'height': '406', 'depth': '3'}, 'segmented': '0', ' ...
# Error during training: must be real number, not dict
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:865: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Type of targets: <class 'list'>
# Content of targets: [{'annotation': {'filename': '2009_004984.jpg', 'folder': 'VOC2012', 'object': [{'name': 'bicycle', 'bndbox': {'xmax': '462', 'xmin': '46', 'ymax': '329', 'ymin': '52'}, 'difficult': '0', 'occluded': '0', 'pose': 'Left', 'truncated': '0'}, {'name': 'bottle', 'bndbox': {'xmax': '250', 'xmin': '197', 'ymax': '220', 'ymin': '160'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '0'}], 'segmented': '0', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2009', 'database': 'The VOC2009 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2010_002143.jpg', 'folder': 'VOC2012', 'object': [{'name': 'cat', 'bndbox': {'xmax': '284', 'xmin': '136', 'ymax': '316', 'ymin': '23'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '0'}], 'segmented': '0', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_004259.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '500', 'height': '399', 'depth': '3'}, 'segmented': '1', 'object': [{'name': 'tvmonitor', 'pose': 'Frontal', 'truncated': '0', 'occluded': '0', 'bndbox': {'xmin': '74', 'ymin': '66', 'xmax': '424', 'ymax': '384'}, 'difficult': '0'}]}}, {'annotation': {'filename': '2010_005951.jpg', 'folder': 'VOC2012', 'object': [{'name': 'car', 'bndbox': {'xmax': '318', 'xmin': '1', 'ymax': '324', 'ymin': '129'}, 'difficult': '0', 'occluded': '0', 'pose': 'Right', 'truncated': '1'}], 'segmented': '1', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2010_003435.jpg', 'folder': 'VOC2012', 'object': [{'name': 'cat', 'bndbox': {'xmax': '499', 'xmin': '1', 'ymax': '375', 'ymin': '1'}, 'difficult': '0', 'occluded': '0', 'pose': 'Unspecified', 'truncated': '1'}], 'segmented': '0', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}, {'annotation': {'filename': '2009_000131.jpg', 'folder': 'VOC2012', 'object': [{'name': 'motorbike', 'bndbox': {'xmax': '500', 'xmin': '365', 'ymax': '274', 'ymin': '90'}, 'difficult': '0', 'occluded': '1', 'pose': 'Right', 'truncated': '1'}, {'name': 'motorbike', 'bndbox': {'xmax': '490', 'xmin': '14', 'ymax': '388', 'ymin': '37'}, 'difficult': '0', 'occluded': '0', 'pose': 'Right', 'truncated': '0'}], 'segmented': '0', 'size': {'depth': '3', 'height': '397', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2009', 'database': 'The VOC2009 Database', 'image': 'flickr'}}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_008095.jpg', 'source': {'database': 'The VOC2008 Database', 'annotation': 'PASCAL VOC2008', 'image': 'flickr'}, 'size': {'width': '500', 'height': '375', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'person', 'pose': 'Frontal', 'truncated': '1', 'occluded': '0', 'bndbox': {'xmin': '1', 'ymin': '32', 'xmax': '363', 'ymax': '375'}, 'difficult': '0'}, {'name': 'bicycle', 'pose': 'Left', 'truncated': '0', 'occluded': '1', 'bndbox': {'xmin': '286', 'ymin': '131', 'xmax': '423', 'ymax': '309'}, 'difficult': '0'}, {'name': 'bicycle', 'pose': 'Right', 'truncated': '1', 'occluded': '0', 'bndbox': {'xmin': '106', 'ymin': '200', 'xmax': '159', 'ymax': '267'}, 'difficult': '1'}, {'name': 'bicycle', 'pose': 'Right', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '1', 'ymin': '142', 'xmax': '92', 'ymax': '302'}, 'difficult': '1'}, {'name': 'person', 'pose': 'Right', 'truncated': '1', 'occluded': '1', 'bndbox': {'xmin': '108', 'ymin': '45', 'xmax': '159', 'ymax': '155'}, 'difficult': '1'}]}}, {'annotation': {'folder': 'VOC2012', 'filename': '2008_005477.jpg', 'source':  ...
# Error during training: must be real number, not dict
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7885b7d65fc0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1477, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1441, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/usr/lib/python3.10/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 931, in wait
#     ready = selector.select(timeout)
#   File "/usr/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-a48357806a50> in <cell line: 1>()
# ----> 1 train(teacher_model, train_loader, epochs, learning_rate, device)
#
# <ipython-input-11-ca0f2cff636b> in train(model, train_loader, epochs, learning_rate, device)
#      16           try:
#      17             images, targets = batch
# ---> 18             images = images.to(device)
#      19
#      20             if images.size(0) == 0:
#
# KeyboardInterrupt:

# %%
def val(model, val_loader, device):
    model.to(device)
    model.eval()

    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    print(f"Test Accuracy: {accuracy:.2f}%")
    return accuracy
